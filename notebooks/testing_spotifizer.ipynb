# %%
from oculizer.spotify import Spotifizer
import os

# %%
credspath = '../spotify_credentials.txt'
with open(credspath) as f:
    lines = f.readlines()
    client_id = lines[0].strip().split(' ')[1]
    client_secret = lines[1].strip().split(' ')[1]
    redirect_uri = lines[2].strip().split(' ')[1]

spotify_controller = Spotifizer(client_id, client_secret, redirect_uri)
# Out:
# Initializing Spotify client...
# Token info: None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       5     client_secret = lines[1].strip().split(' ')[1]
#       6     redirect_uri = lines[2].strip().split(' ')[1]
# ----> 8 spotify_controller = Spotifizer(client_id, client_secret, redirect_uri)
#
# File ~/Documents/creative/Oculizer/oculizer/spotify/spotifizer.py:16, in Spotifizer.__init__(self, client_id, client_secret, redirect_uri, update_interval, time_offset)
#      14 self.info_queue = queue.Queue()
#      15 self.auth_manager = self._create_auth_manager(client_id, client_secret, redirect_uri)
# ---> 16 self.spotify = self._initialize_spotify()
#      17 self.playing = False
#      18 self.current_track_id = None
#
# File ~/Documents/creative/Oculizer/oculizer/spotify/spotifizer.py:45, in Spotifizer._initialize_spotify(self)
#      43 print(f"Token info: {token_info}")
#      44 if not token_info or self.auth_manager.is_token_expired(token_info):
# ---> 45     token_info = self.auth_manager.refresh_access_token(token_info['refresh_token'])
#      46 return Spotify(auth=token_info['access_token'])
#
# TypeError: 'NoneType' object is not subscriptable
